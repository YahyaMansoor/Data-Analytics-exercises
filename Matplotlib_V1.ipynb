# %% [markdown]
# <a href="https://colab.research.google.com/github/YahyaMansoor/Data-Analytics-exercises/blob/main/Matplotlib_V1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Hunting Exoplanets In Space - Scatter & Line Plots

# %% [markdown]
# ---

# %% [markdown]
# #### Loading The Training Dataset
#
# Dataset links (Don't click on them):
#
# 1. Train dataset
#
#    https://student-datasets-bucket.s3.ap-south-1.amazonaws.com/whitehat-ds-datasets/kepler-exoplanets-dataset/exoTrain.csv
#
# 2. Test dataset
#
#    https://student-datasets-bucket.s3.ap-south-1.amazonaws.com/whitehat-ds-datasets/kepler-exoplanets-dataset/exoTest.csv

# %%
# Load the training dataset.
import pandas as pd

exo_train_df = pd.read_csv('https://student-datasets-bucket.s3.ap-south-1.amazonaws.com/whitehat-ds-datasets/kepler-exoplanets-dataset/exoTrain.csv')
exo_train_df.head()
# Out:
#    LABEL   FLUX.1   FLUX.2   FLUX.3   FLUX.4   FLUX.5   FLUX.6  FLUX.7  \
# 0      2    93.85    83.81    20.10   -26.98   -39.56  -124.71 -135.18
# 1      2   -38.88   -33.83   -58.54   -40.09   -79.31   -72.81  -86.55
# 2      2   532.64   535.92   513.73   496.92   456.45   466.00  464.50
# 3      2   326.52   347.39   302.35   298.13   317.74   312.70  322.33
# 4      2 -1107.21 -1112.59 -1118.95 -1095.10 -1057.55 -1034.48 -998.34
#
#     FLUX.8  FLUX.9  ...  FLUX.3188  FLUX.3189  FLUX.3190  FLUX.3191  \
# 0   -96.27  -79.89  ...     -78.07    -102.15    -102.15      25.13
# 1   -85.33  -83.97  ...      -3.28     -32.21     -32.21     -24.89
# 2   486.39  436.56  ...     -71.69      13.31      13.31     -29.89
# 3   311.31  312.42  ...       5.71      -3.73      -3.73      30.05
# 4 -1022.71 -989.57  ...    -594.37    -401.66    -401.66    -357.24
#
#    FLUX.3192  FLUX.3193  FLUX.3194  FLUX.3195  FLUX.3196  FLUX.3197
# 0      48.57      92.54      39.32      61.42       5.08     -39.54
# 1      -4.86       0.76     -11.70       6.46      16.00      19.93
# 2     -20.88       5.06     -11.80     -28.91     -70.02     -96.67
# 3      20.03     -12.67      -8.77     -17.31     -17.35      13.98
# 4    -443.76    -438.54    -399.71    -384.65    -411.79    -510.54
#
# [5 rows x 3198 columns]

# %%
# Check the number of rows and columns in the 'exo_train_df'.
exo_train_df.shape
# Out:
# (5087, 3198)

# %% [markdown]
# ---

# %% [markdown]
# #### Check For The Missing Values

# %%
# Find the total number of missing values in the 'exo_train_df'.
num_missing_values = 0

for column in exo_train_df.columns:
  for item in exo_train_df[column].isnull():
    if item == True:
      num_missing_values += 1

num_missing_values
# Out:
# 0

# %% [markdown]
# There are no missing values in the DataFrame.

# %% [markdown]
# ---

# %% [markdown]
# #### Slicing A DataFrame Using The `iloc[]` Function
# Create Pandas series for the first 3 stars and the last 3 stars in the DataFrame.

# %%
# Create a Pandas series for the first star and store it in a variable called 'star_0'.
star_0 = exo_train_df.iloc[0, :]
star_0.head()
# Out:
# LABEL      2.00
# FLUX.1    93.85
# FLUX.2    83.81
# FLUX.3    20.10
# FLUX.4   -26.98
# Name: 0, dtype: float64

# %% [markdown]
# **Syntax:**
#
# `dataframe_name.iloc[row_position_start : row_position_end, column_position_start : column_position_end]`
#
# In this syntax:
#
# - `row_position_start` denotes the position of the row in the DataFrame **starting** from whose values you want to take in the new Pandas series or DataFrame.
# - `row_position_end` denotes the position of the row in the DataFrame till whose values you want to take in the new Pandas series or DataFrame.
# - `column_position_start` denotes the position of the column in the DataFrame **starting** from whose values you want to take in the new Pandas series or DataFrame.
# - `column_position_end` denotes the position of the column in the DataFrame till whose values you want to take in the new Pandas series or DataFrame.
#
# You can verify manually whether we have extracted the values from the first row or not by viewing the first 5 rows of the DataFrame using the `head()` function.

# %%
# Create a Pandas series for the second star and store it in a variable called 'star_1'.
star_1 = exo_train_df.iloc[1, :]
star_1.head()
# Out:
# LABEL      2.00
# FLUX.1   -38.88
# FLUX.2   -33.83
# FLUX.3   -58.54
# FLUX.4   -40.09
# Name: 1, dtype: float64

# %%
# Create a Pandas series for the third star and store it in a variable called 'star_2'.
star_2 = exo_train_df.iloc[2, :]
star_2.head()
# Out:
# LABEL       2.00
# FLUX.1    532.64
# FLUX.2    535.92
# FLUX.3    513.73
# FLUX.4    496.92
# Name: 2, dtype: float64

# %%
# Create a Pandas series for the last star and store it in a variable called 'star_5086'.
star_5086 = exo_train_df.iloc[5086, :]
star_5086.head()
# Out:
# LABEL       1.00
# FLUX.1    323.28
# FLUX.2    306.36
# FLUX.3    293.16
# FLUX.4    287.67
# Name: 5086, dtype: float64

# %%
# Create a Pandas series for the second-last star and store it in a variable called 'star_5085'.
star_5085 = exo_train_df.iloc[5085, :]
star_5085.head()
# Out:
# LABEL     1.00
# FLUX.1    3.82
# FLUX.2    2.09
# FLUX.3   -3.29
# FLUX.4   -2.88
# Name: 5085, dtype: float64

# %%
# Create a Pandas series for the third-last star and store it in a variable called 'star_5084'.
star_5084 = exo_train_df.iloc[5084, :]
star_5084.head()
# Out:
# LABEL       1.00
# FLUX.1    273.39
# FLUX.2    278.00
# FLUX.3    261.73
# FLUX.4    236.99
# Name: 5084, dtype: float64

# %% [markdown]
# ---

# %% [markdown]
# ### Scatter and Line Plots of Flux
#
# Now that we have Pandas series for the 3 stars labelled as `2` and 3 stars labelled as `1`, let's plot the **Flux** values on the  $y-axis$ for each observation for a star. On $x-axis$, we will plot numbers ranging from `1` to `3197`.

# %% [markdown]
# ---

# %% [markdown]
# #### Activity 1: Scatter And Line Plots For First 3 Stars^
#
# Let's plot the scatter plots and line plots for the first three planets in the `exo_train_df` DataFrame.
#
# To make this plot,
#
# 1. We first need to import a Python module named `matplotlib.pyplot` with `plt` as an alias. This module is exclusively designed for creating graphs such as bar graphs, histogram, line plot, scatter plot etc. We will learn more about this module as we go on in this course. Meanwhile, you can read more about this module by clicking on the link provided in the **Activities** section under the title **The `matplotlib` Documentation**.
#
#   ```
#   import matplotlib.pyplot as plt
#   ```
#
# 2. Then we need to call the `figure()` function from the `plt` module to resize the plot. The `figure()` function takes `figsize=(horizontal_width, vertical_height)` parameter as an input.
#
#   ```
#   plt.figure(figsize=(16, 4))
#   ```
#
# 3. Then we need either a Python list, a NumPy array or a Pandas series containing the numbers between `1` and `3197` to plot them on the $x-axis$.
#
#   ```
#   x_values_star_0 = np.arange(1, 3198)
#   ```
#
# 4. Then we need `star_0` Pandas series to plot the `FLUX` values on the $y-axis$ for the first star in the DataFrame.
#
#   ```
#   y_values_star_0 = star_0[1:]
#   ```
#
# 5. Then we need to call the `scatter()` function from the `plt` module with the required inputs as described in the third and the fourth steps.
#
#   ```
#   plt.scatter(x_values_star_0, y_values_star_0)
#   ```
#
# 6. Finally, we need to call the `show()` function from the `plt` module.
#
#   ```
#   plt.show()
#   ```

# %%
# Create a scatter plot for 'star_0' Pandas series.
# 1. Import the 'numpy' and 'matplotlib.pyplot' modules.
import numpy as np
import matplotlib.pyplot as plt

# 2. Call the 'figure()' function to resize the plot.
plt.figure(figsize=(16, 4))
# Here, 16 means the plot is 16 units wide and 4 units high. Play with these numbers to draw different sized plots.

# Call the 'scatter()' function to make a scatter plot between the x and y values.
# The scatter() function requires two inputs: x and y where x is the data to be plotted on the x-axis and y is the data to be plotted on the y-axis.
# In our case, x is a Pandas series of numbers between 1 and 3197 and y is the 'FLUX' values for a star.

x_values_star_0 = np.arange(1, 3198)
y_values_star_0 = star_0[1:]

# Here, star_0[1:] is a Pandas series containing all the 'FLUX' values starting from the value at index 1 till the value at last index, i.e., 3197
# The 'arange(1, 3198)' function from the 'numpy' module will generate numbers from 1 to 3197.

# 3. Call the 'scatter()' function.
plt.scatter(x_values_star_0, y_values_star_0)

# 4. Call the 'show()' function.
plt.show() 
# The 'show()' function displays the plot.

# %% [markdown]
# As we can see from the graph, there is a somewhat periodic downward peak in the brightness level recorded by the Kepler telescope for this star. This suggests that the first star in the DataFrame has at least one planet.
#
# Let's draw the line plot also to see this fluctuation in a different manner.
#
# To draw a line plot, you have to follow the same steps that you followed to create a scatter plot except in the fifth step, you have to call the `plot()` function instead of the `scatter()` function from the `plt` module.

# %%
# Create a line plot for 'star_0' Pandas series.
# Line plot for the first star in the DataFrame.
plt.figure(figsize=(18, 6))

# Call the plot(x, y) function to draw a line plot between the x and y values.
plt.plot(x_values_star_0, y_values_star_0)
plt.show()

# %% [markdown]
# The line plot also confirms the periodic downward-peaks in the `FLUX` values.

# %%
#  Create a scatter plot for the second star, i.e., 'star_1'.
plt.figure(figsize=(18, 6))
x_values_star_1 = np.arange(1, 3198)
y_values_star_1 = star_1[1:]
plt.scatter(x_values_star_1, y_values_star_1)
plt.show()

# %% [markdown]
# It is quite difficult to spot any clear pattern in the scatter plot for the second star in the DataFrame. Let's draw a line plot to identify a pattern.

# %%
# Create a line plot for the second star, i.e., 'star_1'.
plt.figure(figsize=(18, 6))
plt.plot(x_values_star_1, y_values_star_1)
plt.show()

# %% [markdown]
# As we can see, there are consistent sudden drops in the brightness levels for the second star in the DataFrame. This suggests that the planet is orbiting its star at very high radial speed. Also, the planet could be very close to the star.

# %%
# Create a scatter plot for the third star, i.e., 'star_2'.
plt.figure(figsize=(18, 6))
x_values_star_2 = np.arange(1, 3198)
y_values_star_2 = star_2[1:]
plt.scatter(x_values_star_2, y_values_star_2)
plt.show()

# %% [markdown]
# Here also, we can spot a clear repetitive downward-peaks which confirms that the star has at least one planet.

# %%
#  Create a line plot for the third star, i.e, 'star_2'.
plt.figure(figsize=(18, 6))
plt.plot(x_values_star_2, y_values_star_2)
plt.show()

# %% [markdown]
# The line plot also confirms the repetitive downward-peak pattern.

# %% [markdown]
# ---

# %% [markdown]
# #### Activity 2: Scatter Plots And Line Plots For Last 3 Stars^^^
# Now, let's create the scatter plots and line plots for the last three stars in the DataFrame which have been labelled or classified as `1`.

# %%
#  Create a scatter plot for the last star, i.e., 'star_5086' in the DataFrame.
plt.figure(figsize=(18, 6))
x_values_star_5086 = np.arange(1, 3198)
y_values_star_5086 = star_5086[1:]
plt.scatter(x_values_star_5086, y_values_star_5086)
plt.show()

# %% [markdown]
# As you can see, there is no clear periodic downward-peak in the brightness levels of the light emitted from the star. We cannot make a claim that the star has a planet orbiting it. Let's also create the line plot to confirm our inference.

# %%
#  Create a line plot for the last star, i.e, 'star_5086' in the DataFrame.
plt.figure(figsize=(18, 6))
plt.plot(x_values_star_5086, y_values_star_5086)
plt.show()

# %% [markdown]
# There are some sudden spikes in the line plot but they exist at irregular intervals. So we cannot say for sure that the star has a planet.

# %%
# Create a scatter plot for the second-last star, i.e., 'star_5085' in the DataFrame.
plt.figure(figsize=(18, 6))
x_values_star_5085 = np.arange(1, 3198)
y_values_star_5085 = star_5085[1:]
plt.scatter(x_values_star_5085, y_values_star_5085)
plt.show()

# %% [markdown]
# There is no clear periodic downward-peak pattern in the `FLUX` values for the second-last star.

# %%
# Create a line plot for the second-last star in the DataFrame.
plt.figure(figsize=(18, 6))
plt.plot(x_values_star_5086, y_values_star_5086)
plt.show()

# %% [markdown]
# The line-plot also confirms that there is no clear periodic downward-peak pattern in the `FLUX` values.

# %%
# Create a scatter plot for the third-last star, i.e., 'star_5084' in the DataFrame.
plt.figure(figsize=(18, 6))
x_values_star_5084 = np.arange(1, 3198)
y_values_star_5084 = star_5084[1:]
plt.scatter(x_values_star_5084, y_values_star_5084)
plt.show()

# %% [markdown]
# No clear periodic downward-peak pattern for the third-last star.

# %%
#  Create a line plot for the third-last star in the DataFrame.
plt.figure(figsize=(18, 6))
plt.plot(x_values_star_5084, y_values_star_5084)
plt.show()

# %% [markdown]
# So, this is how we create scatter and line plots for the numeric data.
#
# **Note:** Now you can attempt **Project 4** on your own.

# %% [markdown]
# ---

# %% [markdown]
# # Additional Activities
#
# The activities starting from this point are optional. Please do these activities only if you have time to spare in the class. Otherwise, skip to the **Wrap-Up** section. The additional activities will not be available in the class copy of the notebook. You will have to manually add these activities in the class copy by adding new text cells and code cells.
#
# Moreover, you do not have to do all the additional activities. Depending on the availability of time in a class, you can choose the number of additional activities to perform from this collection.

# %% [markdown]
# ---

# %% [markdown]
# ### Activity 1: Downloading Dataset
#
# Sometimes we get dataset in a `zip` file which contains the `csv` files. The `zip` files are relatively smaller in size compared to the `CSV` file. To get the required `csv` files, we first have to download the `zip` file. Then, we have to extract the `csv` files.
#
# So, let's learn how to download a `zip` file from the data source. Here's the link to the Kepler space telescope dataset `zip` file. Don't click on it. Just copy the link and paste it in the code cell below.
#
# https://student-datasets-bucket.s3.ap-south-1.amazonaws.com/whitehat-ds-datasets/kepler-exoplanets-dataset/kepler-exoplanet-data.zip
#
# To download a file from a URL, you have to use a **bash** command called `!wget` followed by the URL of the file.
#
# Bash is simply a command processor to run a machine. Back in the old days, when computers didn't have a Graphical User-Interface (GUI) and mouse, the computers were used using keyboards by writing various text-based commands. There are different command processors to run computer commands. One of them is Bash. You can read about it more on Wikipedia. Here's the link:
#
# https://en.wikipedia.org/wiki/Bash_(Unix_shell)

# %%
#  Download a file from an external source using the !wget command.
# !wget https://student-datasets-bucket.s3.ap-south-1.amazonaws.com/whitehat-ds-datasets/kepler-exoplanets-dataset/kepler-exoplanet-data.zip
# Out:
# --2020-01-20 16:20:58--  https://student-datasets-bucket.s3.ap-south-1.amazonaws.com/whitehat-ds-datasets/kepler-exoplanets-dataset/kepler-exoplanet-data.zip
# Resolving student-datasets-bucket.s3.ap-south-1.amazonaws.com (student-datasets-bucket.s3.ap-south-1.amazonaws.com)... 52.219.66.87
# Connecting to student-datasets-bucket.s3.ap-south-1.amazonaws.com (student-datasets-bucket.s3.ap-south-1.amazonaws.com)|52.219.66.87|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 58642135 (56M) [application/zip]
# Saving to: ‘kepler-exoplanet-data.zip’
#
# kepler-exoplanet-da 100%[===================>]  55.92M  11.3MB/s    in 6.3s
#
# 2020-01-20 16:21:06 (8.89 MB/s) - ‘kepler-exoplanet-data.zip’ saved [58642135/58642135]

# %% [markdown]
# As you can see, the file called `kepler-exoplanet-data.zip` has been downloaded successfully in the notebook. The files get stored in the Google Colab drive.
#
# **Note:** Generally, the bash commands are used without the exclamation mark (`!`) because they are used on a Linux based terminal. Here, we are using a Jupyter notebook. So, we will always use the bash commands with the exclamation (`!`) mark.

# %% [markdown]
# ---

# %% [markdown]
# #### Activity 2: The `!ls -lh` Command
# The downloaded files get stored in the Google Colab drive. To view all the files stored in Colab drive, you can use the `!ls -lh` command.

# %%
# View the files stored in the Google Colab drive using the !ls -lh command.
# !ls -lh
# Out:
# total 56M
# -rw-r--r-- 1 root root  56M Nov  2 07:11 kepler-exoplanet-data.zip
# drwxr-xr-x 1 root root 4.0K Jan 13 16:38 sample_data

# %% [markdown]
# As you can see, the `kepler-exoplanet-data.zip` has been downloaded successfully. Its size on the Colab drive is 56 MB.

# %% [markdown]
# ---

# %% [markdown]
# #### Activity 3: The `!unzip` Command
# Now that we have downloaded the required `zip` file, we need to unzip it to extract the required `csv` files. Use the `!unzip` command to extract the contents of a `zip` file.
#
# **Syntax:** `!unzip file_name.zip`

# %%
#  Unzip a zip file using the !unzip command.
# !unzip kepler-exoplanet-data.zip
# Out:
# Archive:  kepler-exoplanet-data.zip
#   inflating: exoTest.csv
#   inflating: exoTrain.csv

# %% [markdown]
# As you can see, the `exoTrain.csv` and `exoTest.csv` files have been extracted. For verification, you can use the `!ls -lh` command.

# %%
# Student Action: Use the !ls -lh command to verify whether the required CSV files have been extracted or not.
# !ls -lh
# Out:
# total 334M
# -rw-r--r-- 1 root root  28M Sep 20 12:25 exoTest.csv
# -rw-r--r-- 1 root root 251M Sep 20 12:25 exoTrain.csv
# -rw-r--r-- 1 root root  56M Nov  2 07:11 kepler-exoplanet-data.zip
# drwxr-xr-x 1 root root 4.0K Jan 13 16:38 sample_data

# %% [markdown]
# As you can see, we got our required `csv` files. The `exoTest.csv` file has occupied `28 MB` while another has occupied `251 MB` of the storage space on the Colab drive.

# %% [markdown]
# ---

# %% [markdown]
# #### Activity 4: The `!pwd` Command
# Now, we can load the `csv` files using the `read_csv()` function. But before that we need to know the full path (or location) of these files. We are already present in the directory in which these files are located. We just need to know the full path of this directory.
#
# To check the present working directory, use the `!pwd` command.

# %%
#  Check the present working directory using the !pwd command.
# !pwd
# Out:
# /content

# %% [markdown]
# So, our required `csv` files are located in the location `/content`. So, the full path of the `csv` files is:
# - Train dataset: `/content/exoTrain.csv`
# - Test dataset: `/content/exoTest.csv`
#
# Now, you create two variables called `train` and `test`. In these two variables, load the `csv` files.

# %%
# Student Action: Load the 'exoTrain.csv' file using the 'read_csv()' function and display the first five rows of the DataFrame.
train = pd.read_csv('/content/exoTrain.csv')
train.head()
# Out:
#    LABEL   FLUX.1   FLUX.2   FLUX.3  ...  FLUX.3194  FLUX.3195  FLUX.3196  FLUX.3197
# 0      2    93.85    83.81    20.10  ...      39.32      61.42       5.08     -39.54
# 1      2   -38.88   -33.83   -58.54  ...     -11.70       6.46      16.00      19.93
# 2      2   532.64   535.92   513.73  ...     -11.80     -28.91     -70.02     -96.67
# 3      2   326.52   347.39   302.35  ...      -8.77     -17.31     -17.35      13.98
# 4      2 -1107.21 -1112.59 -1118.95  ...    -399.71    -384.65    -411.79    -510.54
#
# [5 rows x 3198 columns]

# %%
# Student Action: Load the 'exoTest.csv' file using the 'read_csv()' function and display the first five rows of the DataFrame.
test = pd.read_csv('/content/exoTest.csv')
test.head()
# Out:
#    LABEL   FLUX.1   FLUX.2   FLUX.3  ...  FLUX.3194  FLUX.3195  FLUX.3196  FLUX.3197
# 0      2   119.88   100.21    86.46  ...      31.93      35.78     269.43      57.72
# 1      2  5736.59  5699.98  5717.16  ...   -2265.98   -2366.19   -2294.86   -2034.72
# 2      2   844.48   817.49   770.07  ...     -95.23    -162.68     -36.79      30.63
# 3      2  -826.00  -827.31  -846.12  ...      20.25    -120.81    -257.56    -215.41
# 4      2   -39.57   -15.88    -9.16  ...     -81.46     -61.98     -69.34     -17.84
#
# [5 rows x 3198 columns]

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ---
